# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# **Os três status mais frequentes na base são Encaminhado á PGFN com manifestação técnica favorável com um total de 34, Deferido total de 14 e Arquivado a pedido 3 processos.**
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get(url)
data_url = r.json()

# %%
df = pd.DataFrame(data_url['items'])

# %%
# 2) Seu códidata=qui
df.columns
df['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df['data_status'] = df['data_status'].astype(str)
df['ano_status'] = df['data_status'].str.slice(6,10)
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0      13271           Estado  Rio de Janeiro        33  RJ    None
# 1      10002           Estado  Rio de Janeiro        33  RJ    None
# 2       7085           Estado  Rio de Janeiro        33  RJ    None
# 3      13624           Estado  Rio de Janeiro        33  RJ    None
# 4       8556           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001999/2008-12
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001097/2009-67
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000493/2012-72
# 3                                           Deferido  19405.000039/2002-72
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
#
#          data_protocolo                                      tipo_operacao  \
# 0  2009-07-01T03:00:00Z  Operação contratual externa (com garantia da U...
# 1  2009-09-09T03:00:00Z  Operação contratual externa (com garantia da U...
# 2  2012-04-16T03:00:00Z  Operação contratual externa (com garantia da U...
# 3  2002-06-20T03:00:00Z                        Operação contratual interna
# 4  2011-06-30T03:00:00Z  Operação contratual externa (com garantia da U...
#
#               finalidade                           tipo_credor  \
# 0  Desenvolvimento rural  Instituição Financeira Internacional
# 1               Profisco  Instituição Financeira Internacional
# 2         Infraestrutura  Instituição Financeira Internacional
# 3         Infraestrutura       Instituição Financeira Nacional
# 4         Multissetorial  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2                       Corporação Andina de Fomento  Dólar dos EUA
# 3  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status ano_status
# 0   39500000.0                 1                      0  07/07/2009       2009
# 1   19759050.0                 1                      0  28/09/2009       2009
# 2  120666000.0                 1                      0  04/10/2012       2012
# 3   67482400.0                 1                      0  27/06/2002       2002
# 4  112000000.0                 1                      0  04/07/2011       2011

# %%
df['ano_status'].astype(int)
# Out:
# 0     2009
# 1     2009
# 2     2012
# 3     2002
# 4     2011
# 5     2012
# 6     2011
# 7     2006
# 8     2009
# 9     2011
# 10    2016
# 11    2009
# 12    2012
# 13    2012
# 14    2014
# 15    2012
# 16    2013
# 17    2012
# 18    2009
# 19    2002
# 20    2012
# 21    2012
# 22    2009
# 23    2016
# 24    2008
# 25    2016
# 26    2009
# 27    2016
# 28    2012
# 29    2014
# 30    2010
# 31    2006
# 32    2002
# 33    2013
# 34    2013
# 35    2013
# 36    2002
# 37    2009
# 38    2009
# 39    2011
# 40    2013
# 41    2013
# 42    2010
# 43    2012
# 44    2014
# 45    2014
# 46    2013
# 47    2008
# 48    2012
# 49    2011
# 50    2011
# 51    2010
# Name: ano_status, dtype: int32

# %%
df['ano_status'].value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2016     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# **Apenas 1 solicitação com status 'Arquivado por decurso de prazo'.**
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# **É o municipio de Luís Eduardo Magalhães 15 solicitações deferidas.**
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def Estados(sigla_estado, tipo_municipio_estado):
    sigla = sigla_estado
    if (tipo_municipio_estado == 'Municipio') or (tipo_municipio_estado == 'municipio'):
        url ='https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
        url = url.replace('RJ', sigla_estado.upper())
    if (tipo_municipio_estado == 'Estado') or (tipo_municipio_estado == 'estado'):
        url ='https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
        url = url.replace('RJ', sigla_estado.upper())
    r = requests.get(url)
    data_url = r.json()
    df = pd.DataFrame(data_url['items'])
    return df

# %%
df = Estados('MG','Estado')
df.head(2)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      11054           Estado  Minas Gerais        31  MG    None
# 1       6917           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001346/2012-10
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000458/2012-53
#
#          data_protocolo                                      tipo_operacao  \
# 0  2012-10-29T02:00:00Z  Operação contratual interna (com garantia da U...
# 1  2012-07-05T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0                                         Proinveste
# 1  Reestruturação e recomposição do principal de ...
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1                                   Credit Suisse AG  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.326390e+09                 1                      0  02/01/2013
# 1  1.300000e+09                 1                      0  01/11/2012

# %%
# 2) Seu código aqui
df['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df = Estados('BA','Municipio')
df.head(2)
# Out:
#    id_pleito tipo_interessado  interessado  cod_ibge  uf  \
# 0      18861        Município       Coribe   2909109  BA
# 1       8153        Município  Santo Amaro   2928604  BA
#
#                 num_pvl                          status          num_processo  \
# 0  00000.000000/2009-55                        Deferido  17944.000434/2015-47
# 1                  None  Arquivado por decurso de prazo  17944.000724/2014-18
#
#          data_protocolo                tipo_operacao  \
# 0  2015-05-27T03:00:00Z  Operação contratual interna
# 1  2015-07-15T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional                    Caixa Econômica Federal
#
#   moeda       valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  Real  1342249.22                 1                      0  12/06/2015
# 1  Real  4984000.00                 0                      0  09/02/2017

# %%
df_interessado_BA = df.loc[df['status'] == 'Deferido']
df_interessado_BA['interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães    15
# Vitória da Conquista      11
# Lauro de Freitas          10
# Camaçari                  10
# Barreiras                 10
#                           ..
# Mutuípe                    1
# Castro Alves               1
# Caturama                   1
# Gavião                     1
# Piatã                      1
# Name: interessado, Length: 180, dtype: int64

# %%
# 4) Seu código 
df = Estados('BA','Estado')
df.head(5)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      18592           Estado       Bahia        29  BA                  None
# 1      10198           Estado       Bahia        29  BA                  None
# 2      10420           Estado       Bahia        29  BA                  None
# 3       9412           Estado       Bahia        29  BA                  None
# 4      23723           Estado       Bahia        29  BA  PVL02.000640/2016-75
#
#                                               status          num_processo  \
# 0                                           Deferido  19407.000059/2003-12
# 1                                           Deferido  17944.001142/2010-17
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001195/2012-08
# 3                                           Deferido  17944.000975/2010-61
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001273/2016-90
#
#          data_protocolo                                      tipo_operacao  \
# 0  2004-11-17T02:00:00Z                        Operação contratual interna
# 1  2010-08-03T03:00:00Z                        Operação contratual interna
# 2  2013-07-04T03:00:00Z  Operação contratual externa (com garantia da U...
# 3  2010-06-30T03:00:00Z                        Operação contratual interna
# 4  2017-06-06T18:33:06Z  Operação contratual interna (com garantia da U...
#
#                   finalidade                           tipo_credor  \
# 0             Multissetorial       Instituição Financeira Nacional
# 1                       PMAE       Instituição Financeira Nacional
# 2                   Profisco  Instituição Financeira Internacional
# 3  PAC - Copa Pró-Transporte       Instituição Financeira Nacional
# 4             Infraestrutura       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0                    Banco do Nordeste do Brasil S/A  Dólar dos EUA
# 1  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3                            Caixa Econômica Federal           Real
# 4                                Banco do Brasil S/A           Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   10000000.0                 1                      0  03/12/2004
# 1    9905400.0                 1                      0  16/08/2010
# 2   45270000.0                 1                      0  17/07/2013
# 3  541800000.0                 1                      0  21/07/2010
# 4  600000000.0                 1                      1  12/06/2017

# %%
df.to_csv('BA.csv')
